# %%
import os

DIRECTORY = '.././Dataset/PerceptionReasoing/'
os.listdir(DIRECTORY)
# Out:
# ['NarrowRoadway',
#  '.DS_Store',
#  'NavigationDecissionMaking',
#  'UnidirectionalTraffic',
#  'LaneRecognition']
